# %% [markdown]
# # Climatelag\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom climatelag import ClimatelagCalculator\n

# %%
df = pd.read_csv("climatelag_dataset.csv")\ndf.head()\n

# %%
calc = ClimatelagCalculator()\nresult = calc.calculate_climatelag(df)\nresult.head()\n

# %%
result["climatelag_index"].describe()\n

# %%
result.groupby("climatelag_band").size()\n

# %%
result["climatelag_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Climatelag` index is now ready for stress testing.
